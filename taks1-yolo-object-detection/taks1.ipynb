# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 869.0/869.0 kB 19.2 MB/s eta 0:00:0000:01
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

results = model.train(data="/kaggle/input/dataset-domba-sapi-kuda-detection/dataset-clasification-kuda-domba-sapi/data.yaml", epochs=100, imgsz=640)
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 195MB/s]
# Ultralytics YOLOv8.2.78 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
import shutil

folder_path = '/kaggle/working/runs'
archive_path = '/kaggle/working/runs'
shutil.make_archive(archive_path, 'zip', folder_path)
# Out:
# '/kaggle/working/runs.zip'

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

model = YOLO('/kaggle/working/runs/detect/train/weights/best.pt')
image_path = '/kaggle/input/dataset-domba-sapi-kuda-detection/dataset-clasification-kuda-domba-sapi/test/images/sapi-162.jpeg'
image = Image.open(image_path)
results = model(image)

predicted_image = results[0].plot() 
plt.imshow(predicted_image)
plt.axis('off')  
plt.show()
# Out:
# 0: 480x640 1 Sapi, 13.9ms
# Speed: 1.9ms preprocess, 13.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
